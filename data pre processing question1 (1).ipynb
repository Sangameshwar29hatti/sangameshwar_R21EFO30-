# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv("mcdonalds_dataset.csv")

# %%
df.head()
# Out:
#    Unnamed: 0                                   url_for_product  \
# 0           0  https://mcdonalds-menu.co.uk/bacon-mayo-chicken/
# 1           1        https://mcdonalds-menu.co.uk/mayo-chicken/
# 2           2           https://mcdonalds-menu.co.uk/hamburger/
# 3           3               https://mcdonalds-menu.co.uk/fries/
# 4           4        https://mcdonalds-menu.co.uk/cheeseburger/
#
#          product_name  product_availability product_calories product_price  \
# 0  Bacon Mayo Chicken                     1        kcal: 332        £ 1.99
# 1        Mayo Chicken                     1        kcal: 285        £ 1.39
# 2           Hamburger                     1        kcal: 251         £1.19
# 3               Fries                     1        kcal: 237        £ 1.19
# 4        Cheeseburger                     1        kcal: 298         £1.39
#
#    have_sizes  Protein  Carbs   Fat  Salt  Saturates  Sugars
# 0           1     17.0   38.0  12.0  1.40        2.2     4.6
# ...

# %%
df.describe()
# Out:
#        Unnamed: 0  product_availability  have_sizes     Protein       Carbs  \
# count  152.000000            152.000000  152.000000  132.000000  133.000000
# mean    75.500000              0.835526    1.131579   17.400000   36.037594
# std     44.022721              0.371930    0.697054   13.450895   15.945070
# min      0.000000              0.000000    0.000000    0.300000    1.000000
# 25%     37.750000              1.000000    1.000000    5.300000   28.000000
# 50%     75.500000              1.000000    1.000000   14.500000   37.000000
# 75%    113.250000              1.000000    1.000000   26.000000   43.000000
# max    151.000000              1.000000    3.000000   53.000000   96.000000
#
#               Fat        Salt   Saturates      Sugars
# count  133.000000  132.000000  132.000000  129.000000
# mean    15.811278    1.371515    5.649242   11.836434
# std     10.917894    1.042456    4.901869   11.787592
# min      0.100000    0.010000    0.000000    0.200000
# ...

# %%
df.shape
# Out:
# (152, 13)

# %%
df.tail()
# Out:
#      Unnamed: 0                                    url_for_product  \
# 147         147      https://mcdonalds-menu.co.uk/muffin-with-jam/
# 148         148           https://mcdonalds-menu.co.uk/hash-brown/
# 149         149       https://mcdonalds-menu.co.uk/pancakes-syrup/
# 150         150  https://mcdonalds-menu.co.uk/pancakes-sausage-...
# 151         151             https://mcdonalds-menu.co.uk/porridge/
#
#                       product_name  product_availability product_calories  \
# 147                Muffin with Jam                     1        kcal: 214
# 148                     Hash Brown                     1        kcal: 127
# 149               Pancakes & Syrup                     1        kcal: 477
# 150  Pancakes & Sausage with Syrup                     1        kcal: 612
# 151                       Porridge                     1        kcal: 154
#
#     product_price  have_sizes  Protein  Carbs   Fat  Salt  Saturates  Sugars
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 152 entries, 0 to 151
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Unnamed: 0            152 non-null    int64
#  1   url_for_product       134 non-null    object
#  2   product_name          152 non-null    object
#  3   product_availability  152 non-null    int64
#  4   product_calories      152 non-null    object
#  5   product_price         152 non-null    object
#  6   have_sizes            152 non-null    int64
#  7   Protein               132 non-null    float64
#  8   Carbs                 133 non-null    float64
#  9   Fat                   133 non-null    float64
#  10  Salt                  132 non-null    float64
#  11  Saturates             132 non-null    float64
#  12  Sugars                129 non-null    float64
# dtypes: float64(6), int64(3), object(4)
# memory usage: 15.6+ KB

# %%
df.loc[0]
# Out:
# Unnamed: 0                                                             0
# url_for_product         https://mcdonalds-menu.co.uk/bacon-mayo-chicken/
# product_name                                          Bacon Mayo Chicken
# product_availability                                                   1
# product_calories                                               kcal: 332
# product_price                                                     £ 1.99
# have_sizes                                                             1
# Protein                                                             17.0
# Carbs                                                               38.0
# Fat                                                                 12.0
# Salt                                                                 1.4
# Saturates                                                            2.2
# Sugars                                                               4.6
# Name: 0, dtype: object

# %%
df.iloc[0,0]
# Out:
# 0

# %%
df.iloc[[3,4]]
# Out:
#    Unnamed: 0                             url_for_product  product_name  \
# 3           3         https://mcdonalds-menu.co.uk/fries/         Fries
# 4           4  https://mcdonalds-menu.co.uk/cheeseburger/  Cheeseburger
#
#    product_availability product_calories product_price  have_sizes  Protein  \
# 3                     1        kcal: 237        £ 1.19           3      2.3
# 4                     1        kcal: 298         £1.39           1     16.0
#
#    Carbs   Fat  Salt  Saturates  Sugars
# 3   29.0  12.0  0.44        1.1     0.4
# 4   31.0  12.0  1.70        5.5     7.0

# %%
x=df.iloc[:,:-1]

# %%
x
# Out:
#      Unnamed: 0                                    url_for_product  \
# 0             0   https://mcdonalds-menu.co.uk/bacon-mayo-chicken/
# 1             1         https://mcdonalds-menu.co.uk/mayo-chicken/
# 2             2            https://mcdonalds-menu.co.uk/hamburger/
# 3             3                https://mcdonalds-menu.co.uk/fries/
# 4             4         https://mcdonalds-menu.co.uk/cheeseburger/
# ..          ...                                                ...
# 147         147      https://mcdonalds-menu.co.uk/muffin-with-jam/
# 148         148           https://mcdonalds-menu.co.uk/hash-brown/
# 149         149       https://mcdonalds-menu.co.uk/pancakes-syrup/
# 150         150  https://mcdonalds-menu.co.uk/pancakes-sausage-...
# 151         151             https://mcdonalds-menu.co.uk/porridge/
#
#                       product_name  product_availability product_calories  \
# 0               Bacon Mayo Chicken                     1        kcal: 332
# ...

# %%
y=df.iloc[:,:-1]
y
# Out:
#      Unnamed: 0                                    url_for_product  \
# 0             0   https://mcdonalds-menu.co.uk/bacon-mayo-chicken/
# 1             1         https://mcdonalds-menu.co.uk/mayo-chicken/
# 2             2            https://mcdonalds-menu.co.uk/hamburger/
# 3             3                https://mcdonalds-menu.co.uk/fries/
# 4             4         https://mcdonalds-menu.co.uk/cheeseburger/
# ..          ...                                                ...
# 147         147      https://mcdonalds-menu.co.uk/muffin-with-jam/
# 148         148           https://mcdonalds-menu.co.uk/hash-brown/
# 149         149       https://mcdonalds-menu.co.uk/pancakes-syrup/
# 150         150  https://mcdonalds-menu.co.uk/pancakes-sausage-...
# 151         151             https://mcdonalds-menu.co.uk/porridge/
#
#                       product_name  product_availability product_calories  \
# 0               Bacon Mayo Chicken                     1        kcal: 332
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'url_for_product', 'product_name', 'product_availability',
#        'product_calories', 'product_price', 'have_sizes', 'Protein', 'Carbs',
#        'Fat', 'Salt', 'Saturates', 'Sugars'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# Unnamed: 0               0
# url_for_product         18
# product_name             0
# product_availability     0
# product_calories         0
# product_price            0
# have_sizes               0
# Protein                 20
# Carbs                   19
# Fat                     19
# Salt                    20
# Saturates               20
# Sugars                  23
# dtype: int64

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[45], line 1
# ----> 1 label_encoder = LabelEncoder()
#       2 data['categorical_column'] = label_encoder.fit_transform(data['categorical_column'])
#
# NameError: name 'LabelEncoder' is not defined
